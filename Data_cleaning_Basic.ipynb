# %% [markdown]
# <a href="https://colab.research.google.com/github/jinutech0323/cyber-security/blob/main/Data_cleaning_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-3383dfac-1881-432e-9621-3fe5bc412506" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3383dfac-1881-432e-9621-3fe5bc412506">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r'DataSet.xlsx')

# %%
df=pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    9 non-null      object
#  1   Age     8 non-null      float64
#  2   City    7 non-null      object
#  3   Marks   8 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 420.0+ bytes

# %%
df.describe()
# Out:
#              Age      Marks
# count   8.000000   8.000000
# mean   22.375000  75.000000
# std     1.767767  14.822762
# min    20.000000  56.000000
# 25%    21.500000  64.250000
# 50%    22.500000  78.000000
# 75%    23.250000  80.750000
# max    25.000000  98.000000

# %%
df.isnull()
# Out:
#     Name    Age   City  Marks
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False   True   True  False
# 6  False  False   True   True
# 7  False  False  False  False
# 8  False  False  False  False

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      1
# City     2
# Marks    1
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
df
# Out:
#       Name   Age        City  Marks
# 0     devi  20.0  coimbatore   56.0
# 1     kala  23.0  coimbatore   78.0
# 2      raj  25.0     tirupur   98.0
# 3    ramya  22.0      trichy   67.0
# 4  lavanya  24.0       erode   89.0
# 5   kathir   NaN         NaN   78.0
# 6    vimal  22.0         NaN    NaN
# 7     devi  20.0  coimbatore   56.0
# 8     kala  23.0  coimbatore   78.0

# %%
df.drop_duplicates()
# Out:
#       Name   Age        City  Marks
# 0     devi  20.0  coimbatore   56.0
# 1     kala  23.0  coimbatore   78.0
# 2      raj  25.0     tirupur   98.0
# 3    ramya  22.0      trichy   67.0
# 4  lavanya  24.0       erode   89.0
# 5   kathir   NaN         NaN   78.0
# 6    vimal  22.0         NaN    NaN

# %%
df.dropna()
# Out:
#       Name   Age        City  Marks
# 0     devi  20.0  coimbatore   56.0
# 1     kala  23.0  coimbatore   78.0
# 2      raj  25.0     tirupur   98.0
# 3    ramya  22.0      trichy   67.0
# 4  lavanya  24.0       erode   89.0
# 7     devi  20.0  coimbatore   56.0
# 8     kala  23.0  coimbatore   78.0

# %%
df.drop_duplicates()
# Out:
#       Name   Age        City  Marks
# 0     devi  20.0  coimbatore   56.0
# 1     kala  23.0  coimbatore   78.0
# 2      raj  25.0     tirupur   98.0
# 3    ramya  22.0      trichy   67.0
# 4  lavanya  24.0       erode   89.0
# 5   kathir   NaN         NaN   78.0
# 6    vimal  22.0         NaN    NaN

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Name   Age        City  Marks
# 0     devi  20.0  coimbatore   56.0
# 1     kala  23.0  coimbatore   78.0
# 2      raj  25.0     tirupur   98.0
# 3    ramya  22.0      trichy   67.0
# 4  lavanya  24.0       erode   89.0
# 5   kathir   NaN         NaN   78.0
# 6    vimal  22.0         NaN    NaN

# %%
df.dropna()
# Out:
#       Name   Age        City  Marks
# 0     devi  20.0  coimbatore   56.0
# 1     kala  23.0  coimbatore   78.0
# 2      raj  25.0     tirupur   98.0
# 3    ramya  22.0      trichy   67.0
# 4  lavanya  24.0       erode   89.0

# %%
df.fillna("No record")
# Out:
#       Name        Age        City      Marks
# 0     devi       20.0  coimbatore       56.0
# 1     kala       23.0  coimbatore       78.0
# 2      raj       25.0     tirupur       98.0
# 3    ramya       22.0      trichy       67.0
# 4  lavanya       24.0       erode       89.0
# 5   kathir  No record   No record       78.0
# 6    vimal       22.0   No record  No record

# %%
df
# Out:
#       Name   Age        City  Marks
# 0     devi  20.0  coimbatore   56.0
# 1     kala  23.0  coimbatore   78.0
# 2      raj  25.0     tirupur   98.0
# 3    ramya  22.0      trichy   67.0
# 4  lavanya  24.0       erode   89.0
# 5   kathir   NaN         NaN   78.0
# 6    vimal  22.0         NaN    NaN

# %%
df['Marks'].fillna(0,inplace=True)
# Out:
# /tmp/ipython-input-130461783.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(0,inplace=True)

# %%
df
# Out:
#       Name   Age        City  Marks
# 0     devi  20.0  coimbatore   56.0
# 1     kala  23.0  coimbatore   78.0
# 2      raj  25.0     tirupur   98.0
# 3    ramya  22.0      trichy   67.0
# 4  lavanya  24.0       erode   89.0
# 5   kathir   NaN         NaN   78.0
# 6    vimal  22.0         NaN    0.0

# %%
df['Age'].fillna("No data",inplace=True)
# Out:
# /tmp/ipython-input-1014873831.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna("No data",inplace=True)
# /tmp/ipython-input-1014873831.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'No data' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Age'].fillna("No data",inplace=True)

# %%
df
# Out:
#       Name      Age        City  Marks
# 0     devi     20.0  coimbatore   56.0
# 1     kala     23.0  coimbatore   78.0
# 2      raj     25.0     tirupur   98.0
# 3    ramya     22.0      trichy   67.0
# 4  lavanya     24.0       erode   89.0
# 5   kathir  No data         NaN   78.0
# 6    vimal     22.0         NaN    0.0

# %%
df['City'].fillna("No Data",inplace=True)
# Out:
# /tmp/ipython-input-3708776660.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].fillna("No Data",inplace=True)

# %%
df
# Out:
#       Name      Age        City  Marks
# 0     devi     20.0  coimbatore   56.0
# 1     kala     23.0  coimbatore   78.0
# 2      raj     25.0     tirupur   98.0
# 3    ramya     22.0      trichy   67.0
# 4  lavanya     24.0       erode   89.0
# 5   kathir  No data     No Data   78.0
# 6    vimal     22.0     No Data    0.0

# %%
avg=df['Age'].mean()

# %%
avg
# Out:
# np.float64(22.375)

# %%
df['Age'].fillna(avg)
# Out:
# 0    20.000
# 1    23.000
# 2    25.000
# 3    22.000
# 4    24.000
# 5    22.375
# 6    22.000
# 7    20.000
# 8    23.000
# Name: Age, dtype: float64

# %%
df['Age'].fillna(avg,inplace=True)
# Out:
# /tmp/ipython-input-1896283889.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(avg,inplace=True)

# %%
df
# Out:
#       Name     Age        City  Marks
# 0     devi  20.000  coimbatore   56.0
# 1     kala  23.000  coimbatore   78.0
# 2      raj  25.000     tirupur   98.0
# 3    ramya  22.000      trichy   67.0
# 4  lavanya  24.000       erode   89.0
# 5   kathir  22.375         NaN   78.0
# 6    vimal  22.000         NaN    NaN
# 7     devi  20.000  coimbatore   56.0
# 8     kala  23.000  coimbatore   78.0

# %%
df['Marks'].fillna(0,inplace=True)
# Out:
# /tmp/ipython-input-130461783.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(0,inplace=True)

# %%
df
# Out:
#       Name     Age        City  Marks
# 0     devi  20.000  coimbatore   56.0
# 1     kala  23.000  coimbatore   78.0
# 2      raj  25.000     tirupur   98.0
# 3    ramya  22.000      trichy   67.0
# 4  lavanya  24.000       erode   89.0
# 5   kathir  22.375         NaN   78.0
# 6    vimal  22.000         NaN    0.0
# 7     devi  20.000  coimbatore   56.0
# 8     kala  23.000  coimbatore   78.0

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv("out.csv",index=False)

# %%
files.download("out.csv")

# %%
import matplotlib.pyplot as plt
plt.scatter(df['City'],df['Marks'],color="red")
plt.title("city vs marks")
plt.xlabel("city")
plt.ylabel("marks")
plt.show()

# %%
plt.plot(df['City'],df['Marks'],color="red")
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
plt.pie(df['Marks'],labels=df['City'])
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
plt.bar(df['City'],df['Marks'],color="red")

plt.show()

# %%
plt.hist(df['Marks'],color="red",bins=4)

plt.show()

# %%
plt.figure(figsize=(10,8))
plt.suptitle("analysis")
# Out:
# Text(0.5, 0.98, 'analysis')

# %%
plt.subplot(2,2,1)
plt.bar(df['City'], df['Marks'])
plt.title("City vs Marks")
plt.xticks(rotation=45, ha='right')
plt.subplot(2,2,2)
plt.plot(df['City'], df['Marks'])
plt.title("City vs Marks (Line)")
plt.xticks(rotation=45, ha='right')
plt.subplot(2,2,3)
plt.scatter(df['City'], df['Marks'])
plt.xticks(rotation=45, ha='right')
plt.title("City vs Marks")
plt.subplot(2,2,4)
plt.hist(df['Marks'], bins=5)
plt.xticks(rotation=45, ha='right')
plt.title("Marks Distribution")

plt.tight_layout()
plt.savefig('dashboard.png')
plt.show()

# %%
files.download("dashboard.png")
